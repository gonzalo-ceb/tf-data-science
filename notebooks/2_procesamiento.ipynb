# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from sklearn.preprocessing import StandardScaler

# %%
# DIVIDIMOS EL DATASET EN TRAIN Y TEST
train = pd.read_csv('../data/datos.csv')

# %%
# CARGAR STOP WORDS
stop_words = stopwords.words('english')

# %%
train.head()
# Out:
#    rank       book_title  book_price  rating          author  \
# 0     2  The Woman in Me       20.93     4.5  Britney Spears
# 1     2  The Woman in Me       20.93     4.5  Britney Spears
# 2     2  The Woman in Me       20.93     4.5  Britney Spears
# 3     2  The Woman in Me       20.93     4.5  Britney Spears
# 4     2  The Woman in Me       20.93     4.5  Britney Spears
#
#    year_of_publication   genre  \
# 0                 2023  Memoir
# 1                 2023  Memoir
# 2                 2023  Memoir
# 3                 2023  Memoir
# 4                 2023  Memoir
#
#                                                  url  \
# 0  amazon.com/Woman-Me-Britney-Spears/dp/16680090...
# 1  amazon.com/Woman-Me-Britney-Spears/dp/16680090...
# 2  amazon.com/Woman-Me-Britney-Spears/dp/16680090...
# 3  amazon.com/Woman-Me-Britney-Spears/dp/16680090...
# 4  amazon.com/Woman-Me-Britney-Spears/dp/16680090...
#
#                                         review_title          reviewer  \
# 0   Unbelievably impressive. Her torn life on paper.  Murderess Marbie
# 1                         What a heartbreaking story               L J
# 2  Britney you are so invincible! You are an insp...             Jamie
# 3                               Fast Read, Sad Story               KMG
# 4                       Buy it, it’s worth the read!   Stephanie Brown
#
#    reviewer_rating                                 review_description  \
# 0                4  I'm only a third way in. Shipped lightening fa...
# 1                5  "There have been so many times when I was scar...
# 2                5  The media could not be loaded. I personally ha...
# 3                5  I have been a fan of Britney's music since the...
# 4                5  Whether or not you’re a fan, it’s a great read...
#
#    is_verified        date                                       timestamp  \
# 0         True  26-10-2023  Reviewed in the United States October 26, 2023
# 1         True  06-11-2023  Reviewed in the United States November 6, 2023
# 2         True  01-11-2023  Reviewed in the United States November 1, 2023
# 3         True  25-10-2023  Reviewed in the United States October 25, 2023
# 4         True  01-11-2023  Reviewed in the United States November 1, 2023
#
#          asin
# 0  1668009048
# 1  1668009048
# 2  1668009048
# 3  1668009048
# 4  1668009048

# %%
# Procesamiento de Train
train = train.drop(columns=['rank', 'url', 'timestamp', 'asin', 'author', 'year_of_publication', 'date', 'asin', 'book_price','is_verified'])

# Separar los géneros
train['genre'] = train['genre'].str.split(',')
train = train.explode('genre')
train = pd.get_dummies(train, columns=['genre'], drop_first=False)

# Procesamiento de las reseñas de los usuarios con TF-IDF ajustado
tfidf_vectorizer_title = TfidfVectorizer(max_features=100, stop_words=stop_words, max_df=0.8, min_df=5)
tfidf_vectorizer_description = TfidfVectorizer(max_features=100, stop_words=stop_words, max_df=0.8, min_df=5)

# Aplicar TF-IDF
tfidf_title = tfidf_vectorizer_title.fit_transform(train['review_title'].fillna(''))
tfidf_description = tfidf_vectorizer_description.fit_transform(train['review_description'].fillna(''))

# Convertir TF-IDF en DataFrames con prefijos
tfidf_title_df = pd.DataFrame(tfidf_title.toarray(), columns=[f'word_title_{word}' for word in tfidf_vectorizer_title.get_feature_names_out()], index=train.index)
tfidf_description_df = pd.DataFrame(tfidf_description.toarray(), columns=[f'word_desc_{word}' for word in tfidf_vectorizer_description.get_feature_names_out()], index=train.index)

# Eliminar columnas de TF-IDF con palabras de longitud menor a 3
tfidf_title_df = tfidf_title_df.loc[:, [col for col in tfidf_title_df.columns if len(col) > len("word_title_") + 2]]
tfidf_description_df = tfidf_description_df.loc[:, [col for col in tfidf_description_df.columns if len(col) > len("word_desc_") + 2]]

# Concatenarlos
train = pd.concat([train, tfidf_title_df, tfidf_description_df], axis=1)

# Eliminar columnas originales
train.drop(columns=['review_title', 'review_description'], inplace=True)

train.head()
# Out:
#         book_title  rating          reviewer  reviewer_rating  genre_ Action  \
# 0  The Woman in Me     4.5  Murderess Marbie                4          False
# 1  The Woman in Me     4.5               L J                5          False
# 2  The Woman in Me     4.5             Jamie                5          False
# 3  The Woman in Me     4.5               KMG                5          False
# 4  The Woman in Me     4.5   Stephanie Brown                5          False
#
#    genre_ Activities  genre_ Adult  genre_ Adventure  genre_ Alphabet  \
# 0              False         False             False            False
# 1              False         False             False            False
# 2              False         False             False            False
# 3              False         False             False            False
# 4              False         False             False            False
#
#    genre_ Animals  ...  word_desc_two  word_desc_want  word_desc_way  \
# 0           False  ...       0.000000        0.000000       0.299337
# 1           False  ...       0.000000        0.000000       0.127401
# 2           False  ...       0.081837        0.240994       0.000000
# 3           False  ...       0.093898        0.092171       0.233930
# 4           False  ...       0.000000        0.000000       0.000000
#
#    word_desc_well  word_desc_work  word_desc_world  word_desc_would  \
# 0        0.000000        0.092395         0.000000         0.291034
# 1        0.000000        0.000000         0.000000         0.123868
# 2        0.067106        0.083909         0.077308         0.132151
# 3        0.000000        0.000000         0.000000         0.227441
# 4        0.251972        0.000000         0.290281         0.000000
#
#    word_desc_writing  word_desc_year  word_desc_years
# 0           0.268176             0.0         0.000000
# 1           0.000000             0.0         0.000000
# 2           0.000000             0.0         0.080612
# 3           0.093146             0.0         0.277478
# 4           0.000000             0.0         0.000000
#
# [5 rows x 317 columns]

# %%
# EXPORTAMOS LOS DF
train.to_csv('../data/train.csv', index=False)
