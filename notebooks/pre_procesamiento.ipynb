# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler

# %%
# DIVIDIMOS EL DATASET EN TRAIN Y TEST
df_datos = pd.read_csv('../data/datos.csv')
train, test = train_test_split(df_datos, test_size=0.2, random_state=42)

# %%
# ELIMINAMOS REVIEWER_RATING DE TEST
test = test.drop(columns=['reviewer_rating'])

# %%
train.head()
# Out:
#      rank                                         book_title  book_price  \
# 708    81                                       Just Because       12.69
# 239    27  Goodnight, Goodnight Construction Site (Board ...        3.78
# 381    44                                     Goodnight Moon        5.36
# 792    90  Harry Potter and the Prisoner of Azkaban (Harr...       25.97
# 672    78  Israel: A Simple Guide to the Most Misundersto...       15.59
#
#      rating                author  year_of_publication  \
# 708     4.6   Matthew McConaughey                 2023
# 239     4.9  Sherri Duskey Rinker                 2011
# 381     4.9   Margaret Wise Brown                 1947
# 792     4.9          J.K. Rowling                 1999
# 672     4.7            Noa Tishby                 2021
#
#                                                  genre  \
# 708                  Picture Books, Childrens, Fiction
# 239                      Picture Book, Cars and Trucks
# 381                              Childrens, literature
# 792                                            Fantasy
# 672  Nonfiction, History, Politics, Israel, Jewish,...
#
#                                                    url  \
# 708  amazon.com/Just-Because-Matthew-McConaughey/dp...
# 239  amazon.com/Goodnight-Construction-Sherri-Duske...
# 381  amazon.com/Goodnight-Moon-Margaret-Wise-Brown/...
# 792  amazon.com/Harry-Potter-Prisoner-Azkaban-MinaL...
# 672  amazon.com/Israel-Simple-Guide-Misunderstood-C...
#
#                                   review_title          reviewer  \
# 708                    A great gift to live by         A. Slater
# 239                                       Book  Margaret Zahalka
# 381                     Adorable Bedtime Story          Robin M.
# 792                        Absolutely STUNNING     Mom's opinion
# 672  An easy and fun to read history of ISRAEL   WALTER P. LESER
#
#      reviewer_rating                                 review_description  \
# 708                5  Bought copies for my inherited grandsons and a...
# 239                5  It was a gift and he does read this every nigh...
# 381                5  "Goodnight Moon" is a classic bedtime story fo...
# 792                5  Minalima's interactive papercraft is always be...
# 672                5  Today it’s in the news and it’s worth finding ...
#
#      is_verified        date                                       timestamp  \
# 708         True  16-10-2023  Reviewed in the United States October 16, 2023
# 239         True  16-10-2023  Reviewed in the United States October 16, 2023
# 381         True  05-10-2023   Reviewed in the United States October 5, 2023
# 792         True  07-10-2023   Reviewed in the United States October 7, 2023
# 672         True  04-11-2023  Reviewed in the United States November 4, 2023
#
#            asin
# 708   593622030
# 239  1452111731
# 381   694003611
# 792  1338815288
# 672  1982144947

# %%
test.head()
# Out:
#      rank                                         book_title  book_price  \
# 280    34  How to Know a Person: The Art of Seeing Others...       19.89
# 434    50                            How to Catch a Dinosaur        4.66
# 39      6                      Fourth Wing (The Empyrean, 1)       16.99
# 417    48             Where's Bluey?: A Search-and-Find Book        6.93
# 585    69  Hello, Baby Animals: A Durable High-Contrast B...        4.73
#
#      rating                             author  year_of_publication  \
# 280     4.5                     Alice Walstead                 2022
# 434     4.8                       Adam Wallace                 2019
# 39      4.8                     Rebecca Yarros                 2023
# 417     4.8   Penguin Young Readers Licenses (                 2022
# 585     4.9        duopress labs, Julissa Mora                 2016
#
#                                                  genre  \
# 280                        Thriller, mystery, suspense
# 434  Picture Books, Dinosaurs, Childrens, Fiction, ...
# 39                                             Fantasy
# 417                       Childrens, Storytime,Fiction
# 585                  Childrens, Picture Books, Animals
#
#                                                    url  \
# 280  amazon.com/How-Know-Person-Seeing-Others/dp/05...
# 434  amazon.com/How-Catch-Dinosaur-Adam-Wallace/dp/...
# 39   amazon.com/Fourth-Wing-Empyrean-Rebecca-Yarros...
# 417  amazon.com/Wheres-Bluey-Search-Find-Book/dp/05...
# 585  amazon.com/Hello-Baby-Animals-High-Contrast-Bo...
#
#                                           review_title  \
# 280  An Important Book on an Important Topic Taking...
# 434        A Brilliant, Kids Story of Building Courage
# 39   Lords of Discipline + Dragonriders of Pern + ....
# 417                                          Cute book
# 585                                          So cute..
#
#                                               reviewer  \
# 280                                          J.M. Ryan
# 434                                           JoeSanch
# 39                                         Greg Barlin
# 417  Mele , Thank you , so soft nice material great...
# 585                                            Latrice
#
#                                     review_description  is_verified  \
# 280  David Brooks is good at both reporting and syn...         True
# 434  What a great! I love the storyline and emphasi...         True
# 39   I first came across Fourth Wing when I noticed...         True
# 417                   Present for my grand babyThank u         True
# 585  My baby loves this little book, I read it to h...         True
#
#            date                                       timestamp        asin
# 280  30-10-2023  Reviewed in the United States October 30, 2023  059323006X
# 434  10-10-2023  Reviewed in the United States October 10, 2023  1492680524
# 39   17-07-2023     Reviewed in the United States July 17, 2023  1649374046
# 417  24-10-2023  Reviewed in the United States October 24, 2023   593385691
# 585  11-10-2023  Reviewed in the United States October 11, 2023  1938093682

# %%
# PROCESAMIENTO DE TRAIN
train = train.drop(columns=['rank', 'url', 'timestamp', 'asin', 'author', 'year_of_publication', 'date', 'asin'])

# SEPARAMOS LOS GÉNEROS
train['genre'] = train['genre'].str.split(',')
train = train.explode('genre')
train = pd.get_dummies(train, columns=['genre'], drop_first=False)

# IS_VERIFIED A BINARIO
train['is_verified'] = train['is_verified'].apply(lambda x: 1 if x else 0)

# ESCALADO VARIABLES NUMÉRICAS
scaler = StandardScaler()
train[['book_price', 'reviewer_rating', 'rating']] = scaler.fit_transform(train[['book_price', 'reviewer_rating', 'rating']])
train.head()
# Out:
#                                             book_title  book_price    rating  \
# 708                                       Just Because    0.071516 -0.554055
# 708                                       Just Because    0.071516 -0.554055
# 708                                       Just Because    0.071516 -0.554055
# 239  Goodnight, Goodnight Construction Site (Board ...   -1.136580  1.358517
# 239  Goodnight, Goodnight Construction Site (Board ...   -1.136580  1.358517
#
#                 review_title          reviewer  reviewer_rating  \
# 708  A great gift to live by         A. Slater         0.436617
# 708  A great gift to live by         A. Slater         0.436617
# 708  A great gift to live by         A. Slater         0.436617
# 239                     Book  Margaret Zahalka         0.436617
# 239                     Book  Margaret Zahalka         0.436617
#
#                                     review_description  is_verified  \
# 708  Bought copies for my inherited grandsons and a...            1
# 708  Bought copies for my inherited grandsons and a...            1
# 708  Bought copies for my inherited grandsons and a...            1
# 239  It was a gift and he does read this every nigh...            1
# 239  It was a gift and he does read this every nigh...            1
#
#      genre_ Action  genre_ Activities  ...  genre_Nonfiction  \
# 708          False              False  ...             False
# 708          False              False  ...             False
# 708          False              False  ...             False
# 239          False              False  ...             False
# 239          False              False  ...             False
#
#      genre_Personal Finance  genre_Picture Book  genre_Picture Books  \
# 708                   False               False                 True
# 708                   False               False                False
# 708                   False               False                False
# 239                   False                True                False
# 239                   False               False                False
#
#      genre_Romance  genre_Self Help  genre_Self-improvement  \
# 708          False            False                   False
# 708          False            False                   False
# 708          False            False                   False
# 239          False            False                   False
# 239          False            False                   False
#
#      genre_Spiritual Warfare  genre_Spirituality  genre_Thriller
# 708                    False               False           False
# 708                    False               False           False
# 708                    False               False           False
# 239                    False               False           False
# 239                    False               False           False
#
# [5 rows x 125 columns]

# %%
# PROCESAMIENTO DE LAS REVIEWS DE LOS USUARIOS
tfidf_vectorizer_title = TfidfVectorizer(max_features=100)
tfidf_vectorizer_description = TfidfVectorizer(max_features=100)

# APLICAR TF-IDF
tfidf_title = tfidf_vectorizer_title.fit_transform(train['review_title'].fillna(''))
tfidf_description = tfidf_vectorizer_description.fit_transform(train['review_description'].fillna(''))

# CONVERTIR TF-IDF EN DATAFRAMES
tfidf_title_df = pd.DataFrame(tfidf_title.toarray(), columns=tfidf_vectorizer_title.get_feature_names_out(), index=train.index)
tfidf_description_df = pd.DataFrame(tfidf_description.toarray(), columns=tfidf_vectorizer_description.get_feature_names_out(), index=train.index)

# CONTATENARLOS
train = pd.concat([train, tfidf_title_df, tfidf_description_df], axis=1)

# ELIMINAR ORIGINALES
train.drop(columns=['review_title', 'review_description'], inplace=True)

train.head()
# Out:
#                                             book_title  book_price    rating  \
# 708                                       Just Because    0.071516 -0.554055
# 708                                       Just Because    0.071516 -0.554055
# 708                                       Just Because    0.071516 -0.554055
# 239  Goodnight, Goodnight Construction Site (Board ...   -1.136580  1.358517
# 239  Goodnight, Goodnight Construction Site (Board ...   -1.136580  1.358517
#
#              reviewer  reviewer_rating  is_verified  genre_ Action  \
# 708         A. Slater         0.436617            1          False
# 708         A. Slater         0.436617            1          False
# 708         A. Slater         0.436617            1          False
# 239  Margaret Zahalka         0.436617            1          False
# 239  Margaret Zahalka         0.436617            1          False
#
#      genre_ Activities  genre_ Adult  genre_ Adventure  ...  were  what  when  \
# 708              False         False             False  ...   0.0   0.0   0.0
# 708              False         False             False  ...   0.0   0.0   0.0
# 708              False         False             False  ...   0.0   0.0   0.0
# 239              False         False             False  ...   0.0   0.0   0.0
# 239              False         False             False  ...   0.0   0.0   0.0
#
#      which  who      will  with  would  you  your
# 708    0.0  0.0  0.222732   0.0    0.0  0.0   0.0
# 708    0.0  0.0  0.222732   0.0    0.0  0.0   0.0
# 708    0.0  0.0  0.222732   0.0    0.0  0.0   0.0
# 239    0.0  0.0  0.000000   0.0    0.0  0.0   0.0
# 239    0.0  0.0  0.000000   0.0    0.0  0.0   0.0
#
# [5 rows x 323 columns]

# %%
# PROCESAMIENTO DE TEST
test = test.drop(columns=['rank', 'url', 'timestamp', 'asin', 'author', 'year_of_publication', 'date', 'asin'])

# SEPARAMOS LOS GÉNEROS
test['genre'] = test['genre'].str.split(',')
test = test.explode('genre')
test = pd.get_dummies(test, columns=['genre'], drop_first=False)

# NOS ASEGURAMOS DE QUE TEST TENGA LOS MISMOS GÉNEROS QUE TRAIN
missing_genres = set(train.columns) - set(test.columns)
for col in missing_genres:
    if 'genre_' in col:  # Agregar columnas de género faltantes
        test[col] = 0

# IS_VERIFIED A BINARIO
test['is_verified'] = test['is_verified'].apply(lambda x: 1 if x else 0)

# ESCALADO DE VARIABLES NUMÉRICAS 
scaler_test = StandardScaler()
scaler_test.fit(train[['book_price', 'rating']])
test[['book_price', 'rating']] = scaler_test.transform(test[['book_price', 'rating']])

# PROCESAMIENTO DE LAS REVIEWS DE LOS USUARIOS
tfidf_title_test = tfidf_vectorizer_title.transform(test['review_title'].fillna(''))
tfidf_description_test = tfidf_vectorizer_description.transform(test['review_description'].fillna(''))

# CONVERTIR TF-IDF EN DATAFRAMES
tfidf_title_test_df = pd.DataFrame(tfidf_title_test.toarray(), columns=tfidf_vectorizer_title.get_feature_names_out(), index=test.index)
tfidf_description_test_df = pd.DataFrame(tfidf_description_test.toarray(), columns=tfidf_vectorizer_description.get_feature_names_out(), index=test.index)

# CONCATENAR LOS RESULTADOS TF-IDF CON EL DATAFRAME ORIGINAL 'test'
test = pd.concat([test, tfidf_title_test_df, tfidf_description_test_df], axis=1)

# ELIMINAR COLUMNAS ORIGINALES DE TEXTO
test.drop(columns=['review_title', 'review_description'], inplace=True)

# VERIFICAMOS QUE TEST TENGA TODAS LAS COLUMNAS TF-IDF FALTANTES QUE ESTÉN EN TRAIN
missing_tfidf_columns = set(train.columns) - set(test.columns)
for col in missing_tfidf_columns:
    if col.startswith('review_title') or col.startswith('review_description'):  # Agregar columnas TF-IDF faltantes
        test[col] = 0

# VERIFICAMOS QUE TEST TENGA EL MISMO NÚMERO DE COLUMNAS QUE TRAIN
train_columns = set(train.columns) - {'reviewer_rating'}
test_columns = set(test.columns)
assert train_columns == test_columns, "Train y Test no tienen las mismas columnas (excepto 'reviewer_rating')"

test.head()
# Out:
#                                             book_title  book_price  rating  \
# 280  How to Know a Person: The Art of Seeing Others...       19.89     4.5
# 280  How to Know a Person: The Art of Seeing Others...       19.89     4.5
# 280  How to Know a Person: The Art of Seeing Others...       19.89     4.5
# 434                            How to Catch a Dinosaur        4.66     4.8
# 434                            How to Catch a Dinosaur        4.66     4.8
#
#       reviewer  is_verified  genre_ Action  genre_ Activities  genre_ Adult  \
# 280  J.M. Ryan            1          False              False         False
# 280  J.M. Ryan            1          False              False         False
# 280  J.M. Ryan            1          False              False         False
# 434   JoeSanch            1          False              False         False
# 434   JoeSanch            1          False              False         False
#
#      genre_ Adventure  genre_ Alphabet  ...  were      what  when  which  who  \
# 280             False            False  ...   0.0  0.039245   0.0    0.0  0.0
# 280             False            False  ...   0.0  0.039245   0.0    0.0  0.0
# 280             False            False  ...   0.0  0.039245   0.0    0.0  0.0
# 434             False            False  ...   0.0  0.293592   0.0    0.0  0.0
# 434             False            False  ...   0.0  0.293592   0.0    0.0  0.0
#
#          will      with     would  you  your
# 280  0.042132  0.030076  0.043924  0.0   0.0
# 280  0.042132  0.030076  0.043924  0.0   0.0
# 280  0.042132  0.030076  0.043924  0.0   0.0
# 434  0.000000  0.000000  0.000000  0.0   0.0
# 434  0.000000  0.000000  0.000000  0.0   0.0
#
# [5 rows x 322 columns]

# %%
# EXPORTAMOS LOS DF
train.to_csv('../data/train.csv', index=False)
test.to_csv('../data/test.csv', index=False)
